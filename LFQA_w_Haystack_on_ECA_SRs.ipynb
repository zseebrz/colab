# %% [markdown]
# # Long-Form Question Answering
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/deepset-ai/haystack/blob/master/tutorials/Tutorial12_LFQA.ipynb)

# %% [markdown]
# ### Prepare environment
#
# #### Colab: Enable the GPU runtime
# Make sure you enable the GPU runtime to experience decent speed in this tutorial.
# **Runtime -> Change Runtime type -> Hardware accelerator -> GPU**
#
# <img src="https://raw.githubusercontent.com/deepset-ai/haystack/master/docs/_src/img/colab_gpu_runtime.jpg">

# %%
# Make sure you have a GPU running
# !nvidia-smi
# Out:
# Sun Nov  7 14:18:35 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Install the latest master of Haystack
# !pip install git+https://github.com/deepset-ai/haystack.git

# If you run this notebook on Google Colab, you might need to
# restart the runtime after installing haystack.
# Out:
# Collecting git+https://github.com/deepset-ai/haystack.git
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-2v_7yv3d
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-2v_7yv3d
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (57.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (0.37.0)
# Requirement already satisfied: torch<1.10,>1.5 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (1.9.0+cu111)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (2.23.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (1.4.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (0.0)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.1 MB/s
# Collecting mlflow<=1.13.1
#   Downloading mlflow-1.13.1-py3-none-any.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 32 kB/s
# Collecting transformers==4.7.0
#   Downloading transformers-4.7.0-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 27.2 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (0.3.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (5.4.8)
# Collecting fastapi
#   Downloading fastapi-0.70.0-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 561 kB/s
# Collecting uvicorn
#   Downloading uvicorn-0.15.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.2 MB/s
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.6 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (1.1.5)
# Collecting elasticsearch<=7.10,>=7.7
#   Downloading elasticsearch-7.10.0-py2.py3-none-any.whl (321 kB)
#      |████████████████████████████████| 321 kB 49.3 MB/s
# Collecting elastic-apm
#   Downloading elastic_apm-6.6.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (351 kB)
#      |████████████████████████████████| 351 kB 43.0 MB/s
# Collecting tox
#   Downloading tox-3.24.4-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.5 MB/s
# Requirement already satisfied: coverage in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (3.7.1)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 34.6 MB/s
# Collecting pytesseract==0.3.7
#   Downloading pytesseract-0.3.7.tar.gz (13 kB)
# Collecting pillow==8.3.2
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 34.5 MB/s
# Collecting pdf2image==1.14.0
#   Downloading pdf2image-1.14.0-py3-none-any.whl (10 kB)
# Collecting sentence-transformers>=0.4.0
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 4.8 MB/s
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 17.5 MB/s
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (1.4.25)
# Collecting sqlalchemy_utils
#   Downloading SQLAlchemy_Utils-0.37.9-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 8.0 MB/s
# Collecting faiss-cpu>=1.6.3
#   Downloading faiss_cpu-1.7.1.post2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.4 MB)
#      |████████████████████████████████| 8.4 MB 15.3 MB/s
# Collecting tika
#   Downloading tika-1.24.tar.gz (28 kB)
# Collecting httptools
#   Downloading httptools-0.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (402 kB)
#      |████████████████████████████████| 402 kB 43.5 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (3.2.5)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (8.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (2.6.3)
# Collecting pymilvus
#   Downloading pymilvus-1.1.2-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.1 MB/s
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-1.8.5-py3-none-any.whl (26 kB)
# Collecting mmh3
#   Downloading mmh3-3.0.0-cp37-cp37m-manylinux2010_x86_64.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.5 MB/s
# Collecting weaviate-client==2.5.0
#   Downloading weaviate_client-2.5.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.3 MB/s
# Collecting ray==1.5.0
#   Downloading ray-1.5.0-cp37-cp37m-manylinux2014_x86_64.whl (51.5 MB)
#      |████████████████████████████████| 51.5 MB 51 kB/s
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.5.6-py3-none-any.whl (25 kB)
# Collecting quantulum3
#   Downloading quantulum3-0.7.9-py3-none-any.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 2.7 MB/s
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 22.4 MB/s
# Collecting uvloop==0.14
#   Downloading uvloop-0.14.0-cp37-cp37m-manylinux2010_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 29.9 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (7.1.2)
# Collecting pydantic>=1.8
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 21.6 MB/s
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.12.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (2.6.0)
# Collecting redis>=3.5.0
#   Downloading redis-3.5.3-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 452 kB/s
# Collecting aioredis
#   Downloading aioredis-2.0.0-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 6.7 MB/s
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.10-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 35.8 MB/s
# Collecting opencensus
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 41.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.3.0)
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.19.5)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.0.2)
# Collecting aiohttp
#   Downloading aiohttp-3.8.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 34.1 MB/s
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.17.3)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.41.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.13)
# Collecting gpustat
#   Downloading gpustat-0.6.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 6.3 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 38.3 MB/s
# Collecting huggingface-hub==0.0.8
#   Downloading huggingface_hub-0.0.8-py3-none-any.whl (34 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (4.8.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (21.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 29.3 MB/s
# Collecting validators>=0.18.2
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.0.0rc1) (2021.5.30)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.0.0rc1) (1.24.3)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio>=1.28.1->ray==1.5.0->farm-haystack==1.0.0rc1) (1.15.0)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.16.2.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 5.9 MB/s
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 45.4 MB/s
# Requirement already satisfied: sqlparse>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.4.2)
# Collecting azure-storage-blob>=12.0.0
#   Downloading azure_storage_blob-12.9.0-py2.py3-none-any.whl (356 kB)
#      |████████████████████████████████| 356 kB 50.3 MB/s
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.18.5-py3-none-any.whl (17 kB)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.1.4)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 40.9 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.8.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.3.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.3)
# Collecting alembic<=1.4.1
#   Downloading alembic-1.4.1.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 38.9 MB/s
# Collecting Mako
#   Downloading Mako-1.1.5-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.3 MB/s
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting cryptography>=2.1.4
#   Downloading cryptography-35.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 32.2 MB/s
# Collecting azure-core<2.0.0,>=1.10.0
#   Downloading azure_core-1.20.0-py2.py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 48.1 MB/s
# Collecting msrest>=0.6.21
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.0 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.20)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.7->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.8.9)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.7.4.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.3.0)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.2 MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.0.0rc1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.0.0rc1) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.1.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (0.10.0+cu111)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (0.22.2.post1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 48.4 MB/s
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.4.2->farm-haystack==1.0.0rc1) (1.1.2)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from validators>=0.18.2->weaviate-client==2.5.0->farm-haystack==1.0.0rc1) (4.4.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (21.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.0-py3-none-any.whl (6.1 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 48.1 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (2.0.7)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 44.4 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 46.1 MB/s
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.14.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.5 MB/s
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting starlette==0.16.0
#   Downloading starlette-0.16.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 247 kB/s
# Collecting anyio<4,>=3.0.0
#   Downloading anyio-3.3.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.1 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.0.1)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray==1.5.0->farm-haystack==1.0.0rc1) (7.352.0)
# Collecting blessings>=1.6
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.7.0->farm-haystack==1.0.0rc1) (3.6.0)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (1.26.3)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (1.53.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (2018.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (4.2.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.7.0->farm-haystack==1.0.0rc1) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.4.8)
# Collecting ujson>=2.0.0
#   Downloading ujson-4.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (214 kB)
#      |████████████████████████████████| 214 kB 48.6 MB/s
# Collecting grpcio>=1.28.1
#   Downloading grpcio-1.37.1-cp37-cp37m-manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 33.4 MB/s
# Collecting grpcio-tools<1.38.0,>=1.22.0
#   Downloading grpcio_tools-1.37.1-cp37-cp37m-manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 32.9 MB/s
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx->farm-haystack==1.0.0rc1) (4.2.6)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from quantulum3->farm-haystack==1.0.0rc1) (2.1.0)
# Collecting num2words
#   Downloading num2words-0.5.10-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 8.8 MB/s
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from num2words->quantulum3->farm-haystack==1.0.0rc1) (0.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.7.0->farm-haystack==1.0.0rc1) (1.0.1)
# Collecting rdflib>=4.0
#   Downloading rdflib-6.0.2-py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 43.1 MB/s
# Requirement already satisfied: py>=1.4.17 in /usr/local/lib/python3.7/dist-packages (from tox->farm-haystack==1.0.0rc1) (1.10.0)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.7/dist-packages (from tox->farm-haystack==1.0.0rc1) (0.10.2)
# Collecting pluggy>=0.12.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0
#   Downloading virtualenv-20.10.0-py2.py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 22.2 MB/s
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.3-py2.py3-none-any.whl (496 kB)
#      |████████████████████████████████| 496 kB 44.4 MB/s
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.4.0-py3-none-any.whl (14 kB)
# Collecting backports.entry-points-selectable>=1.0.4
#   Downloading backports.entry_points_selectable-1.1.0-py2.py3-none-any.whl (6.2 kB)
# Collecting h11>=0.8
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.0 MB/s
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Building wheels for collected packages: farm-haystack, pytesseract, alembic, databricks-cli, sentence-transformers, gpustat, langdetect, python-docx, python-multipart, seqeval, tika
#   Building wheel for farm-haystack (setup.py) ... done
#   Created wheel for farm-haystack: filename=farm_haystack-1.0.0rc1-py3-none-any.whl size=353332 sha256=cc5bb110e3c001a1b76c3bd1995d0604c92966619f13f130177629246bb09abf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l67obzz8/wheels/a7/05/3b/9b33368d9af06a39f8e6af2e97fa2af876e893ade323cfc2c9
#   Building wheel for pytesseract (setup.py) ... done
#   Created wheel for pytesseract: filename=pytesseract-0.3.7-py2.py3-none-any.whl size=13954 sha256=1bf01b83f978521764f9f59b7dc0a686b4e6f8714fdb712ec4d6ec51485b1b88
#   Stored in directory: /root/.cache/pip/wheels/67/71/6c/7a8c5ca2e699752506999ae7baeb692e2b4fc6488c2cddcb22
#   Building wheel for alembic (setup.py) ... done
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158172 sha256=daf0063e00bac1e5544cbcd780d555614f66aa25767cddab09496498dc1ed565
#   Stored in directory: /root/.cache/pip/wheels/be/5d/0a/9e13f53f4f5dfb67cd8d245bb7cdffe12f135846f491a283e3
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.16.2-py3-none-any.whl size=106811 sha256=695d329895cf20c1f47a9aefdb100a9e87440a99d0fd857f2f14b8c8a66bad98
#   Stored in directory: /root/.cache/pip/wheels/f4/5c/ed/e1ce20a53095f63b27b4964abbad03e59cf3472822addf7d29
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=d10d0effd8c5894ed6180c51813da58e7331bbdb7c7f07ee3661729a2bc99595
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-py3-none-any.whl size=12617 sha256=904db07942e4e65058faf3e6822f7148e9e6f663ac6c65213d7a5a275767089d
#   Stored in directory: /root/.cache/pip/wheels/e6/67/af/f1ad15974b8fd95f59a63dbf854483ebe5c7a46a93930798b8
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=c2839212394ac5ccdb347458a4e5265b094362118fe23a2fccf9b46a8820fd89
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=e0400c5de73bc91c74723f59aa9720235ae2d78bb73c41e0d615f26d2ee6fbce
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=82add9218336d8f176cda6695d21a78ef4c9d8aa0f0bf62c48db2f84c6b72776
#   Stored in directory: /root/.cache/pip/wheels/2c/41/7c/bfd1c180534ffdcc0972f78c5758f89881602175d48a8bcd2c
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=3f2f50e7fb1823aa7985b3959d240c9ed039b84eacc8c2efcff658e1f12802b8
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32891 sha256=d614410bc734a382885fc1d9a476089e6c1a431c12108d493144b9d608dda894
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built farm-haystack pytesseract alembic databricks-cli sentence-transformers gpustat langdetect python-docx python-multipart seqeval tika
# Installing collected packages: multidict, frozenlist, yarl, sniffio, smmap, isodate, asynctest, async-timeout, aiosignal, websocket-client, tokenizers, sacremoses, python-editor, platformdirs, pillow, opencensus-context, mypy-extensions, msrest, marshmallow, Mako, huggingface-hub, grpcio, gitdb, distlib, cryptography, blessings, backports.entry-points-selectable, azure-core, anyio, aiohttp, virtualenv, validators, ujson, typing-inspect, transformers, starlette, sentencepiece, redis, rdflib, querystring-parser, pydantic, py-spy, prometheus-flask-exporter, pluggy, opencensus, num2words, marshmallow-enum, h11, gunicorn, grpcio-tools, gpustat, gitpython, docker, databricks-cli, colorama, azure-storage-blob, asgiref, alembic, aioredis, aiohttp-cors, weaviate-client, uvloop, uvicorn, tox, tika, sqlalchemy-utils, SPARQLWrapper, seqeval, sentence-transformers, ray, quantulum3, python-multipart, python-docx, pytesseract, pymilvus, psycopg2-binary, pdf2image, mmh3, mlflow, langdetect, httptools, fastapi, faiss-cpu, elasticsearch, elastic-apm, dataclasses-json, farm-haystack
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.41.0
#     Uninstalling grpcio-1.41.0:
#       Successfully uninstalled grpcio-1.41.0
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytest 3.6.4 requires pluggy<0.8,>=0.5, but you have pluggy 1.0.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Mako-1.1.5 SPARQLWrapper-1.8.5 aiohttp-3.8.0 aiohttp-cors-0.7.0 aioredis-2.0.0 aiosignal-1.2.0 alembic-1.4.1 anyio-3.3.4 asgiref-3.4.1 async-timeout-4.0.0 asynctest-0.13.0 azure-core-1.20.0 azure-storage-blob-12.9.0 backports.entry-points-selectable-1.1.0 blessings-1.7 colorama-0.4.4 cryptography-35.0.0 databricks-cli-0.16.2 dataclasses-json-0.5.6 distlib-0.3.3 docker-5.0.3 elastic-apm-6.6.1 elasticsearch-7.10.0 faiss-cpu-1.7.1.post2 farm-haystack-1.0.0rc1 fastapi-0.70.0 frozenlist-1.2.0 gitdb-4.0.9 gitpython-3.1.24 gpustat-0.6.0 grpcio-1.37.1 grpcio-tools-1.37.1 gunicorn-20.1.0 h11-0.12.0 httptools-0.3.0 huggingface-hub-0.0.8 isodate-0.6.0 langdetect-1.0.9 marshmallow-3.14.0 marshmallow-enum-1.5.1 mlflow-1.13.1 mmh3-3.0.0 msrest-0.6.21 multidict-5.2.0 mypy-extensions-0.4.3 num2words-0.5.10 opencensus-0.8.0 opencensus-context-0.1.2 pdf2image-1.14.0 pillow-8.3.2 platformdirs-2.4.0 pluggy-1.0.0 prometheus-flask-exporter-0.18.5 psycopg2-binary-2.9.1 py-spy-0.3.10 pydantic-1.8.2 pymilvus-1.1.2 pytesseract-0.3.7 python-docx-0.8.11 python-editor-1.0.4 python-multipart-0.0.5 quantulum3-0.7.9 querystring-parser-1.2.4 ray-1.5.0 rdflib-6.0.2 redis-3.5.3 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 seqeval-1.2.2 smmap-5.0.0 sniffio-1.2.0 sqlalchemy-utils-0.37.9 starlette-0.16.0 tika-1.24 tokenizers-0.10.3 tox-3.24.4 transformers-4.7.0 typing-inspect-0.7.1 ujson-4.2.0 uvicorn-0.15.0 uvloop-0.14.0 validators-0.18.2 virtualenv-20.10.0 weaviate-client-2.5.0 websocket-client-1.2.1 yarl-1.7.2

# %%
from haystack.utils import convert_files_to_dicts, fetch_archive_from_http, clean_wiki_text
from haystack.nodes import Seq2SeqGenerator
# Out:
# /usr/local/lib/python3.7/dist-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   "update your install command.", FutureWarning)

# %% [markdown]
# ### Document Store
#
# FAISS is a library for efficient similarity search on a cluster of dense vectors.
# The `FAISSDocumentStore` uses a SQL(SQLite in-memory be default) database under-the-hood
# to store the document text and other meta data. The vector embeddings of the text are
# indexed on a FAISS Index that later is queried for searching answers.
# The default flavour of FAISSDocumentStore is "Flat" but can also be set to "HNSW" for
# faster search at the expense of some accuracy. Just set the faiss_index_factor_str argument in the constructor.
# For more info on which suits your use case: https://github.com/facebookresearch/faiss/wiki/Guidelines-to-choose-an-index

# %%
from haystack.document_stores import FAISSDocumentStore

document_store = FAISSDocumentStore(vector_dim=128, faiss_index_factory_str="Flat")

# %% [markdown]
# ### Cleaning & indexing documents
#
# Similarly to the previous tutorials, we download, convert and index some Game of Thrones articles to our DocumentStore

# %%
# Let's first get some files that we want to use
doc_dir = "data/article_txt_got"
s3_url = "https://s3.eu-central-1.amazonaws.com/deepset.ai-farm-qa/datasets/documents/wiki_gameofthrones_txt.zip"
s3_url = "https://github.com/zseebrz/SR_EU_added_value/raw/master/52_document_corpus_30_sept.zip"
fetch_archive_from_http(url=s3_url, output_dir=doc_dir)

# Convert files to dicts
dicts = convert_files_to_dicts(dir_path=doc_dir, clean_func=clean_wiki_text, split_paragraphs=True)
    
# Now, let's write the dicts containing documents to our DB.
document_store.write_documents(dicts)

# %% [markdown]
# ### Initalize Retriever and Reader/Generator
#
# #### Retriever
#
# **Here:** We use a `RetribertRetriever` and we invoke `update_embeddings` to index the embeddings of documents in the `FAISSDocumentStore`

# %%
from haystack.nodes import EmbeddingRetriever

retriever = EmbeddingRetriever(document_store=document_store,
                               embedding_model="yjernite/retribert-base-uncased",
                               model_format="retribert")

document_store.update_embeddings(retriever)
# Out:
# Downloading:   0%|          | 0.00/487 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/325M [00:00<?, ?B/s]
# Some weights of RetriBertModel were not initialized from the model checkpoint at yjernite/retribert-base-uncased and are newly initialized: ['bert_query.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Updating Embedding:   0%|          | 0/507 [00:00<?, ? docs/s]
# Creating Embeddings:   0%|          | 0/16 [00:00<?, ? Batches/s]
# Documents Processed: 10000 docs [00:39, 254.11 docs/s]

# %% [markdown]
# Before we blindly use the `RetribertRetriever` let's empirically test it to make sure a simple search indeed finds the relevant documents.

# %%
from haystack.utils import print_documents
from haystack.pipelines import DocumentSearchPipeline

p_retrieval = DocumentSearchPipeline(retriever)
res = p_retrieval.run(
    query="Tell me something about cybersecurity?",
    params={"Retriever": {"top_k": 10}}
)
print_documents(res, max_text_len=512)
# Out:
# Query: Tell me something about cybersecurity?
#
# {   'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\n'
#                'The Common External Relations Information System (CRIS)\n'
#                'together with the Commissions replies\n'
#                'Despite some weakenesses, CRIS is now being developed to \n'
#                'respond to the Commissions needs\t24-44\n'
#                'System development projects now respond to well identified \n'
#                'Need for an up-to-date definition of CRISs role\t30-35\n'
#                'Persisting problems with user friendliness\t42-44\n'
#                'CRIS management is not yet sufficiently effective in '
#                'ensuring \n'
#                'Insufficient security of the system and...',
#     'name': 'DVC009318EN04-12PP-CH365-12APCFIN-RS-CRIS_final-ORAN.doc.txt'}
#
# {   'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\n'
#                'The European Institute of Innovation and Technology must '
#                'modify its delivery mechanisms and elements of its design to '
#                'achieve the expected impact\n'
#                "Together with the Commission's replies\n"
#                'Europe is lagging behind in innovation\t1 - 2\n'
#                'Shift in EU policy focus towards innovation\t3 - 6\n'
#                'The European Institute of Innovation and Technology\t7 - 13\n'
#                'The EIT’s mission and objective\t7 - 8\n'
#                'Audit scope and approach\t14 - 18\n'
#                'The EIT is based on a valid rationale\t19 - 23\n'
#                '...',
#     'name': 'text_SR_2016_04_EIT.txt'}
#
# {   'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\n'
#                'The European Institute of Innovation and Technology must '
#                'modify its delivery \n'
#                'mechanisms and elements of its design to achieve the expected '
#                'impact\n'
#                "Together with the Commission's replies\n"
#                'Europe is lagging behind in innovation\t1 - 2\n'
#                'Shift in EU policy focus towards innovation\t3 - 6\n'
#                'The European Institute of Innovation and Technology\t7 - 13\n'
#                'The EITs mission and objective\t7 - 8\n'
#                'Audit scope and approach\t14 - 18\n'
#                'The EIT is based on a valid rationale\t19 - 23\n'
#                '...',
#     'name': 'PRF066103EN05-15PP-CH331-15APCFIN-RS-EIT-ORAN.docx.txt'}
#
# {   'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\n'
#                'Lessons from the European Commissions development of the '
#                'second generation \n'
#                'Schengen Information System (SIS II)\n'
#                "together with the Commission's replies\n"
#                'Section 1 - \tThe Commission delivered SIS II albeit \n'
#                'The initial project deadline was unrealistic\t9 - 12\n'
#                'Until 2007 the Commission did not allocate sufficient staff \n'
#                'with the expertise to manage outsourced development work \n'
#                'Working relations between some member countries and the  \n'
#                'Commission were initia...',
#     'name': 'PRF009520EN05-13PP-CH410-13APCFIN-RS-SIS_II-ORAN.docx.txt'}
#
# {   'content': 'Technology is opening up a whole new world of opportunities, '
#                'with new products and services becoming integral parts of our '
#                'daily lives. In turn, the risk of falling victim to cybercrime '
#                'or a cyberattack is increasing, the societal and economic '
#                'impact of which continues to mount. The EU’s recent drive '
#                'since 2017 to accelerate efforts to strengthen cybersecurity '
#                'and its digital autonomy come therefore at a critical time.\n'
#                'This briefing paper, which is not an audit report and is based '
#                'on publicly available info...',
#     'name': 'text_BRP_2019_EU_Cybersecurity_policy.txt'}
#
# {   'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\n'
#                'Single Supervisory Mechanism - Good start but further '
#                'improvements needed\n'
#                'Establishment of the European banking union\t6 - 12\n'
#                'Audit approach and methodology\t13 - 19\n'
#                'Difficulty in obtaining audit evidence\t19\n'
#                'A complex organisational structure was set up\t21 - 27\n'
#                'The ECB’s recruitment for the SSM was effective given the time '
#                'constraints…\t25\n'
#                '…but is heavily reliant on NCA resources\t26 - 27\n'
#                'The institutional bodies have been set up as required, '
#                'supported by ...',
#     'name': 'text_SR_2016_29_SSM.txt'}
#
# {   'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\n'
#                'Single Resolution Board: Work on a challenging Banking Union '
#                'task started, but still a long way to go\n'
#                'Together with the SRB’s replies\n'
#                'Role of the Single Resolution Board\t5 - 8\n'
#                'The SRB’s interaction with other authorities\t9 - 12\n'
#                'Audit scope and approach\t13 - 23\n'
#                'Audit scope and methodology\t13 - 21\n'
#                'Access to evidence and confidentiality issues\t22 - 23\n'
#                'Resolution plans: still very much a work in progress\t24 - 83\n'
#                'Overview of resolution plan content\t35 - 36\n'
#                '...',
#     'name': 'text_SR_2017_23_SRB.txt'}
#
# {   'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\n'
#                'Is the design and management of the mobility scheme of the '
#                'Leonardo da \n'
#                'likely to lead to effective results?\n'
#                'Together with the Commission’s replies.\n'
#                'Role of the National Authority\t9\n'
#                'The Commission took account of its own mandatory  \n'
#                'evaluations of the predecessor programme, but did not  \n'
#                'systematically take account of other important studies  \n'
#                'The Commission established an appropriate system for  \n'
#                'project life cycle management. The supporting IT system...',
#     'name': 'PIN001711EN07-10PP-CH087-10APCFIN-RS-LdV-ORAN.doc.txt'}
#
# {   'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\n'
#                'EIOPA made an important contribution to supervision and '
#                'stability in the insurance sector,\n'
#                'but significant challenges remain\n'
#                'Together with the replies of EIOPA\n'
#                'The insurance market in the European economy\t1 - 3\n'
#                'EIOPA as part of the European system of financial supervision\t'
#                '4 - 6\n'
#                'Audit scope and approach\t9 - 13\n'
#                'Part I - EIOPA’s actions to ensure consistent supervision by '
#                'NCAs are sound, but lack a systematic approach to follow-up\t'
#                '14 - 22\n'
#                'EIOPA identified...',
#     'name': 'text_SR_2018_29_EIOPA.txt'}
#
# {   'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\n'
#                'The use of budget support to improve domestic revenue '
#                'mobilisation in subSaharan\xa0Africa\n'
#                "together with the Commission's and the EEAS’ replies\n"
#                'Domestic revenue mobilisation is important for sustainable '
#                'development\t1 - 2\n'
#                'DRM is a priority for the international development community\t'
#                '3\n'
#                'The EU is committed to supporting DRM\t4 - 7\n'
#                'DRM is one of the key development challenges addressed with '
#                'budget support\t8 - 14\n'
#                'Audit scope and approach\t15 - 18\n'
#                'The Commission’...',
#     'name': 'text_SR_2016_35_Africa_revenue_published2017.txt'}

# %% [markdown]
# #### Reader/Generator
#
# Similar to previous Tutorials we now initalize our reader/generator.
#
# Here we use a `Seq2SeqGenerator` with the *yjernite/bart_eli5* model (see: https://huggingface.co/yjernite/bart_eli5)

# %%
generator = Seq2SeqGenerator(model_name_or_path="yjernite/bart_eli5")
# Out:
# Downloading:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]

# %% [markdown]
# ### Pipeline
#
# With a Haystack `Pipeline` you can stick together your building blocks to a search pipeline.
# Under the hood, `Pipelines` are Directed Acyclic Graphs (DAGs) that you can easily customize for your own use cases.
# To speed things up, Haystack also comes with a few predefined Pipelines. One of them is the `GenerativeQAPipeline` that combines a retriever and a reader/generator to answer our questions.
# You can learn more about `Pipelines` in the [docs](https://haystack.deepset.ai/docs/latest/pipelinesmd).

# %%
from haystack.pipelines import GenerativeQAPipeline
pipe = GenerativeQAPipeline(generator, retriever)

# %% [markdown]
# ## Voilà! Ask a question!

# %%
pipe.run(
    query="What is the water quality situation in Romania?",
    params={"Retriever": {"top_k": 1}}
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# {'answers': [" It's not that the water quality is bad, it's that there's no money to be made to fix it."],
#  'documents': [{'content': '(pursuant to Article 287(4), second subparagraph, TFEU)\nIs EU Structural Measures spending on the supply of water for domestic \ntogether with the Commission’s replies\nEU Structural Measures co-financing of water supply \nAudit scope and objectives\t11 - 15\nWere the most appropriate solutions adopted in order to meet \nthe needs of the areas concerned?\t16 - 35\nIn almost all cases, forecasts of needs did not take into \naccount downward trends in per capita water consumption, \nand in some cases, not all resources already available were \nThe focus is on building infrastructures to exploit new water \nsources and attention is rarely paid to other solutions, \nsuch as reducing water losses, …\t25 - 27\n… or using more accessible resources\t28\nLimited value was added by the grant applications’ \nappraisal by the Commission and the Member States’ \nHave the projects achieved their aims of improving the supply \nof water for domestic consumption?\t36 - 48\nProject objectives were not always quantified with regard \nProjects achieved measurable improvements in the water \nsupply to EU citizens, but ...\t41 - 42\n... some projects were not in operation because of missing \n... and other projects contained inherent limitations\t44\nReporting on achievements has been of limited value\t45 - 48\nHave the results been achieved at the lowest cost to the EU \nEconomy is affected by delays and cost overruns\t50 - 52\nSeveral projects operate with limited efficiency\t53 - 59\nProcess for setting grant rates shows significant \n… and does not take sufficient account  of the ability of the \nprojects to generate revenue\t64 - 70\nConclusions and recommendations\t71 - 75\nAnnex II - Projects selected for the audit\nAnnex III - Household water expenditure and disposable incomes in the \nAll infrastructure enabling the provision of water in \nmunicipal/local tanks, including water abstraction, \nproduction, the long-distance transfer of raw water, \ntreatment and transport up to the tanks. Water is then \nprovided to users through the distribution network.\nFinancial instrument designed to strengthen economic \nand social cohesion by financing environment and \ntransport projects in Member States with a per capita \nGNP of less than 90 % of the EU average. \nA technique for comparing all the costs and all the \nbenefits of an intervention to determine whether the \nbenefits outweigh the costs, and if so, by what proportion.\nA principle requiring that the costs of a specific good or \nservice are covered by the revenues.\nIn the field of water, Member States are required to adopt \nwater pricing policies which take account of the recovery \nof all costs in order to provide incentives to use water \nresources efficiently (see Article 9 of Directive \n2000/60/EC of the European Parliament and of the \nCouncil of 23 October 2000 establishing a framework for \nCommunity action in the field of water policy (OJ L 327, \nAll activities and infrastructures enabling the distribution \nof water to domestic and other users from municipal or \nMeasurement of the relationship between objectives set \nMeasurement of the relationship between the resources \nemployed and the results achieved. In the present report, \nthe relationship between investment cost and, for \nexample, the increase in water volumes supplied or the \nimprovement in the quality of the water.\nFinancial instrument designed to promote economic and \nsocial cohesion between the regions of the EU. ERDF \ninterventions are mainly implemented through operational \nprogrammes involving a large number of projects.\nHectocubic metre, equals 1 million m3.\nA year in the future for which the estimated demand is \nused as a basis for planning water supply investment.\nDifference between the volume of water abstracted and \nthe invoiced consumption, also known as unaccounted-\nfor water. It includes leakages, illegal consumption, \ninaccuracies in measurement and free u ...
#  'node_id': 'Generator',
#  'params': {'Retriever': {'top_k': 1}},
#  'query': 'What is the water quality situation in Romania?',
#  'root_node': 'Query'}

# %%
pipe.run(query="Is high-speed rail expensive in Spain?", params={"Retriever": {"top_k": 1}})
# Out:
# {'answers': [' High speed rail is expensive in Spain because it takes a long time to build and maintain a high speed rail network. It takes a lot of money to build a rail network, and it takes even more money to maintain it.'],
#  'documents': [{'content': "(pursuant to Article 287(4), second subparagraph, TFEU)\nA European high-speed rail network: \nnot a reality but an ineffective patchwork\ntogether with the Commission’s replies\nHigh-speed rail in Europe\t1 - 2\nThe EU’s high-speed rail network is growing in size and in rate of utilisation\t3 - 4\nEU policies for high-speed rail\t5 - 9\nEU support for building high-speed lines: significant, but a fraction of total cost\t10 - 13\nAudit scope and approach\t14 - 20\nEU co-funded investments in high-speed rail can be beneficial, but there is no solid EU-wide strategic approach\t21 - 36\nHigh-speed rail is a beneficial mode of transport which contributes to the EU’s sustainable-mobility objectives\t21 - 22\nThe Commission's powers are limited, and its plan to triple the length of the high-speed rail network is unlikely to be achieved\t23 - 26\nMember States plan and decide on their national networks, leading to a patchwork of poorly connected national high-speed networks\t27 - 36\nDecision-making lacks reliable cost-benefit analyses\t37 - 58\n“Very high-speed” is not needed everywhere\t37 - 44\nCost-efficiency checks are rare\t45 - 48\nCost-benefit analyses are not used as a tool for decision-making in the Member States\t49 - 51\nCost overruns, construction delays and delayed entry into service: a norm instead of an exception\t52 - 58\nA citizen’s view: a real-life assessment of travel times, prices and connections, of passenger-services and of stations and their catchment area\t59 - 77\nTravel times and ticket prices, are important factors for success\t59 - 63\nFurther improvements needed to rail ticketing, and in monitoring passenger-services data\t64 - 67\nThe number and location of stations are both important\t68 - 77\nHigh-speed rail sustainability: effectiveness of the EU co-funding at risk\t78 - 85\nPassenger data analysis: three of the seven completed high-speed rail lines carry fewer passengers than the benchmark of nine million per year\t79\nCatchment-area analysis of the number of people living along the lines: nine of 14 audited high-speed lines and stretches do not have sufficient high number of potential passengers\t80 - 82\nThe competitiveness of high-speed rail compared to other modes of transport: there is no “polluter-pays” principle yet\t83 - 85\nSeamless and competitive cross-border high-speed rail operations: not yet universal\t86 - 95\nWith many barriers still existing, there is a long way to go before markets become open and competitive on high-speed lines in the EU\t86 - 88\nTrack access charges: overly complicated, and a potential hindrance to competition\t89 - 92\nA strong and independent regulator: necessary, but not always a reality\t93 - 95\nConclusions and recommendations\t96 - 106\nHigh-speed rail operations have many advantages but there is no realistic long term EU plan, and there is no truly EU high-speed network\t96 - 98\nThe principles of sound financial management have not consistently been applied for the audited high-speed rail infrastructure investments\t99 - 100\nAssessing the situation for the EU citizens highlights the advantages of high-speed rail, while the sustainability of the EU co-funding to high-speed lines is at risk\t101 - 103\nSeamless and competitive cross-border high-speed rail operations are still some way off\t104 - 106\nAnnex I – European High-Speed Network Map\nAnnex II – Overview of HSR funding since 2000 by MS and management mode\nAnnex III – Analysis of projects\nAnnex IV – Key HSR Data per Member State\nAnnex VI – A citizen's view: Assessement of travel times, prices and connections on the audited high-speed rail lines: the methodology and the data\nAnnex VII – Impact of stations on travel time and speed\nAnnex VIII – Map of the catchment area and key data for each of the audited HSLs, as well as for the border crossings assessed\nAnnex IX – Analysis of stations\nHigh-speed rail is a comfortable, safe, flexible and environmentally sustainabl ...
#  'node_id': 'Generator',
#  'params': {'Retriever': {'top_k': 1}},
#  'query': 'Is high-speed rail expensive in Spain?',
#  'root_node': 'Query'}

# %% [markdown]
# ## About us
#
# This [Haystack](https://github.com/deepset-ai/haystack/) notebook was made with love by [deepset](https://deepset.ai/) in Berlin, Germany
#
# We bring NLP to the industry via open source!
# Our focus: Industry specific language models & large scale QA systems.
#
# Some of our other work:
# - [German BERT](https://deepset.ai/german-bert)
# - [GermanQuAD and GermanDPR](https://deepset.ai/germanquad)
# - [FARM](https://github.com/deepset-ai/FARM)
#
# Get in touch:
# [Twitter](https://twitter.com/deepset_ai) | [LinkedIn](https://www.linkedin.com/company/deepset-ai/) | [Slack](https://haystack.deepset.ai/community/join) | [GitHub Discussions](https://github.com/deepset-ai/haystack/discussions) | [Website](https://deepset.ai)
#
# By the way: [we're hiring!](https://www.deepset.ai/jobs)
